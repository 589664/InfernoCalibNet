# %%
import config
from src.utils.Tools import compute_mean_std_rgb_dataset

# Paths to directories
xray_dir = config.RAW_DIR / "xrays"

(mean_r, std_r), (mean_g, std_g), (mean_b, std_b) = compute_mean_std_rgb_dataset(xray_dir)
# Out:
# Computing mean and std: 100%|██████████| 2188/2188 [07:58<00:00,  4.57batch/s]
# Final Mean - R: 0.5463, G: 0.5463, B: 0.5463
# Final Std - R: 0.2366, G: 0.2366, B: 0.2366
